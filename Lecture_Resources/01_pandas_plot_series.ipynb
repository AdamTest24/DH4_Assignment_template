# %%
from pandas import read_csv

from matplotlib.pyplot import subplots

from numpy import arange, linspace, zeros

# %%
df = read_csv("data/EEG_background.txt", delim_whitespace=True) 

df.head()
# Out:
#        FP1      FP2        F3       F4        C3       C4      P3       P4  \
# 0  -7.4546  22.8428   6.28159  15.6212   7.98755  22.4034 -7.7884  32.6146
# 1 -11.1060  21.4828   6.89088  15.0562  10.10910  22.5443 -7.1574  34.1495
# 2 -14.4000  20.0907   7.94856  14.1624  13.00190  21.6666 -6.1377  34.6890
# 3 -17.2380  18.7206   9.36857  13.0093  16.52820  19.9170 -4.6946  34.2955
# 4 -19.5540  17.4084  11.06040  11.6674  20.51280  17.4778 -2.7760  33.1315
#
#         O1       O2  ...      Pz       A1       A2      EKG      ATM      EO1  \
# 0  35.6545  24.8028  ... -11.775  38.8505  35.2711  2.35162  14.1170  13.6331
# 1  34.8749  29.5059  ... -12.350  44.9804  61.4472  1.89293  14.2920  13.7184
# 2  34.1256  33.6971  ... -13.006  46.2484  79.1628  1.22726  14.4623  13.7995
# 3  33.6028  37.5240  ... -13.580  43.3831  88.4718  0.30236  14.6182  13.8759
# 4  33.5562  41.1388  ... -13.886  36.7796  89.8117 -0.85890  14.7537  13.9521
#
#        EO2      EM1      EM2      PHO
# 0  13.7021  12.9109  13.7034  9.37573
# 1  13.7942  13.0194  13.7628  9.44731
# 2  13.8982  13.1116  13.8239  9.51796
# 3  14.0155  13.1927  13.8914  9.58770
# 4  14.1399  13.2692  13.9652  9.65654
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (2373, 28)

# %% [markdown]
# # Pandas Time Series Plot

# %%
df.plot();

# %%
df.plot(colormap='hsv', legend=False);
